# %%
import data_utils

dataset = data_utils.get_dataset()
dataset.head()
# Out:
#      AFEC_DPTO       AFEC_EDADR                 AFEC_EDUC AFEC_GENERO  \
# 0  bogota d.c.  de 13 a 17 años                   ninguno       mujer
# 1       nariño    de 0 a 5 años                   ninguno      hombre
# 2        valle  de 13 a 17 años                secundaria      hombre
# 3        huila  de 13 a 17 años  universitario incompleto      hombre
# 4    risaralda  de 13 a 17 años                   ninguno      hombre
#
#   AFEC_GETNICO     AFEC_MPIO AFEC_PARENTESCO  \
# 0    no aplica        bogotá            otro
# 1    no aplica       puerres            otro
# 2    no aplica          cali      abuelo (a)
# 3    no aplica         neiva           padre
# 4    no aplica  dosquebradas           padre
#
#                        AFEC_POBESPECIAL AFEC_REGAFILIACION AFEC_TIPOPER  \
# 0                             no aplica         subsidiado      natural
# 1                             no aplica         subsidiado      natural
# 2                             no aplica       contributivo      natural
# 3                             no aplica       contributivo      natural
# 4  persona en condición de discapacidad       contributivo      natural
#
#     ...        PET_MPIO PET_TIPOPER      PQR_CANAL PQR_CLASE_SNS  \
# 0   ...          bogotá    juridica        escrito           pqr
# 1   ...         puerres     natural     telefonico           pqr
# 2   ...            cali     natural     telefonico           pqr
# 3   ...           neiva     natural  personalizado           pqr
# 4   ...    dosquebradas     natural  personalizado           pqr
#
#            PQR_ESTADO PQR_GRUPOALERTA  PQR_TIPOATENCION PQR_TIPOPETICION  \
# 0             cerrado               0  peticion directa         reclamo
# 1             cerrado               0                 0         reclamo
# 2             cerrado               0                 0         reclamo
# 3             cerrado               0                 0         reclamo
# 4  pendiente (avance)               0                 0         reclamo
#
#   RIESGO_VIDA    TRIM
# 0          no  trim i
# 1          no  trim i
# 2          no  trim i
# 3          no  trim i
# 4          si  trim i
#
# [5 rows x 46 columns]

# %%
dataset = data_utils.clean_afec_dpto(dataset)
dataset = data_utils.clean_riesgo_vida(dataset)
dataset = data_utils.clean_cie_10(dataset)
dataset = data_utils.remove_features(dataset)
dataset = dataset.reset_index()
dataset = dataset.drop(['index'], axis = 1)
# Out:
# /Users/mrugeles/Documents/DataScience/Supersalud-PQRSD/data_utils.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dataset['RIESGO_VIDA'] = np.where(dataset['RIESGO_VIDA'] == 'si', 1,0)

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
for column in dataset.columns:
    le.fit(dataset[column])
    dataset[column] = le.transform(dataset[column]) 

dataset.head()
# Out:
#    AFEC_DPTO  AFEC_EDADR  AFEC_EDUC  AFEC_GENERO  AFEC_GETNICO  AFEC_MPIO  \
# 0          5           2          1            2             5        123
# 1         31           2          5            1             5        161
# 2         18           2          8            1             5        676
# 3         26           2          1            1             5        322
# 4          5           2          1            1             5        123
#
#    AFEC_PARENTESCO  AFEC_POBESPECIAL  AFEC_REGAFILIACION  AFEC_TIPOPER  ...   \
# 0               12                 4                   5             2  ...
# 1                1                 4                   1             2  ...
# 2               13                 4                   1             2  ...
# 3               13                 5                   1             2  ...
# 4               12                 4                   5             2  ...
#
#    PATOLOGIA_TIPO  PET_COD_DEPTO  PET_MPIO  PET_TIPOPER  PQR_CANAL  \
# 0             368              1       121            1          2
# 1             368             23       159            2          4
# 2             368             11       655            2          3
# 3             179             19       310            2          3
# 4             368              1       121            1          2
#
#    PQR_CLASE_SNS  PQR_TIPOATENCION  PQR_TIPOPETICION  RIESGO_VIDA  TRIM
# 0              0                 3                 3            0     0
# 1              0                 0                 3            0     0
# 2              0                 0                 3            0     0
# 3              0                 0                 3            1     0
# 4              0                 3                 3            0     0
#
# [5 rows x 36 columns]

# %% [markdown]
# ## Store processed dataset

# %%
dataset.to_csv("datasets/basic_dataset.csv", index = False)
