# %%
import pandas as pd

naive = pd.read_csv('naive_dataset_model.csv')
naive
# Out:
#                         learner   train_time  pred_time    f_test   f_train
# 0             BaggingClassifier   618.157443  10.590624  0.711715  0.966804
# 1        RandomForestClassifier    92.975928   7.265372  0.700315  0.966914
# 2        DecisionTreeClassifier    65.953366   0.855501  0.687318  0.998385
# 3          ExtraTreesClassifier    63.556398   9.226027  0.668347  0.998385
# 4    GradientBoostingClassifier   776.843183   4.028940  0.659510  0.657730
# 5                 XGBClassifier   442.187489   6.474289  0.647582  0.647049
# 6           ExtraTreeClassifier     5.668401   0.979424  0.637806  0.998385
# 7            AdaBoostClassifier   388.104872   8.084650  0.602438  0.603548
# 8            LogisticRegression   101.310741   0.423634  0.324973  0.320610
# 9             RidgeClassifierCV     7.057977   0.403060  0.322185  0.318935
# 10                MLPClassifier  1779.778368  19.587020  0.253515  0.249721
# ...

# %%
basic_dataset_model = pd.read_csv('basic_dataset_model.csv')
basic_dataset_model
# Out:
#                         learner  train_time  pred_time    f_test   f_train
# 0                 XGBClassifier   32.640871   0.813968  0.785668  0.789449
# 1    GradientBoostingClassifier   37.832539   0.474781  0.782356  0.786724
# 2                 MLPClassifier  344.666835   1.787835  0.775120  0.777671
# 3             BaggingClassifier   22.298211   1.050560  0.764236  0.981039
# 4        RandomForestClassifier    4.286101   0.850535  0.746783  0.981922
# 5            AdaBoostClassifier   10.336274   0.937033  0.741645  0.745364
# 6        DecisionTreeClassifier    3.320874   0.093776  0.735845  0.999089
# 7          ExtraTreesClassifier    4.155299   1.135921  0.705083  0.999089
# 8           ExtraTreeClassifier    0.476864   0.125889  0.666358  0.999089
# 9            LogisticRegression   21.647002   0.024820  0.595042  0.599155
# 10              RidgeClassifier    0.097321   0.022661  0.577202  0.582304
# ...

# %%
missing_state_dataset_model = pd.read_csv('missing_state_dataset_model.csv')
missing_state_dataset_model
# Out:
#                         learner  train_time  pred_time    f_test   f_train
# 0                 XGBClassifier   54.631729   1.032161  0.786597  0.790686
# 1    GradientBoostingClassifier   56.811249   0.705668  0.783447  0.787737
# 2             BaggingClassifier   28.864257   1.339352  0.763491  0.980989
# 3        RandomForestClassifier    4.977574   1.011794  0.744717  0.981549
# 4        DecisionTreeClassifier    3.982649   0.109896  0.733374  0.999089
# 5            AdaBoostClassifier   12.991749   1.108130  0.732205  0.735300
# 6          ExtraTreesClassifier    5.157242   1.306665  0.706307  0.999089
# 7           ExtraTreeClassifier    0.532683   0.160517  0.666214  0.999089
# 8                 MLPClassifier  470.255732   2.228532  0.646924  0.657343
# 9            LogisticRegression   24.863498   0.042238  0.595527  0.600945
# 10              RidgeClassifier    0.188617   0.045933  0.583848  0.589383
# ...

# %%
missing_state_75_dataset_model = pd.read_csv('missing_state_75_dataset_model.csv')
missing_state_75_dataset_model
# Out:
#                         learner  train_time  pred_time    f_test   f_train
# 0                 XGBClassifier   50.985813   0.993253  0.783830  0.788220
# 1    GradientBoostingClassifier   55.816394   0.686719  0.779842  0.783881
# 2             BaggingClassifier   27.116534   1.286923  0.764988  0.981456
# 3        RandomForestClassifier    5.204913   0.999789  0.740860  0.981334
# 4            AdaBoostClassifier   11.942934   1.083012  0.732474  0.737011
# 5        DecisionTreeClassifier    3.780796   0.108612  0.730639  0.999059
# 6                 MLPClassifier  407.208937   1.950148  0.724288  0.729822
# 7          ExtraTreesClassifier    5.261061   1.245440  0.695911  0.999059
# 8           ExtraTreeClassifier    0.500657   0.156597  0.668282  0.999059
# 9            LogisticRegression   21.101294   0.041283  0.581520  0.590042
# 10              RidgeClassifier    0.191591   0.041965  0.568790  0.577306
# ...

# %%
model = pd.read_csv('missing_state_impute_dataset_model.csv')
model
# Out:
#                         learner  train_time  pred_time    f_test   f_train
# 0                 XGBClassifier   50.919745   0.998418  0.784690  0.789663
# 1    GradientBoostingClassifier   54.000495   0.731073  0.782181  0.786669
# 2                 MLPClassifier  552.690213   2.644473  0.766528  0.768058
# 3             BaggingClassifier   26.927148   1.323842  0.763283  0.980853
# 4            AdaBoostClassifier   12.614667   1.395266  0.740434  0.747016
# 5        RandomForestClassifier    5.296800   1.044780  0.738109  0.981036
# 6        DecisionTreeClassifier    3.874627   0.145555  0.735413  0.999059
# 7          ExtraTreesClassifier    5.131650   1.420990  0.686298  0.999059
# 8           ExtraTreeClassifier    0.551401   0.197115  0.672796  0.999059
# 9               RidgeClassifier    0.166990   0.048742  0.556393  0.563333
# 10            RidgeClassifierCV    0.975276   0.053407  0.553498  0.558833
# ...

# %%
model = pd.read_csv('impute_dataset_model.csv')
model
# Out:
#                         learner  train_time  pred_time    f_test   f_train
# 0                 XGBClassifier   33.588891   0.875692  0.786924  0.788579
# 1    GradientBoostingClassifier   39.268308   0.496563  0.782035  0.785070
# 2             BaggingClassifier   24.205076   1.113727  0.757030  0.981068
# 3            AdaBoostClassifier    9.891672   0.974110  0.740820  0.746545
# 4        RandomForestClassifier    4.616387   0.907289  0.739226  0.981226
# 5        DecisionTreeClassifier    3.449403   0.101733  0.729910  0.999037
# 6          ExtraTreesClassifier    4.733986   1.398482  0.702147  0.999037
# 7           ExtraTreeClassifier    0.467804   0.149607  0.668516  0.999037
# 8                 MLPClassifier  350.380414   2.195180  0.653585  0.658914
# 9            LogisticRegression   19.065591   0.026965  0.563144  0.568652
# 10            RidgeClassifierCV    0.602932   0.027915  0.552156  0.558536
# ...

# %%
model = pd.read_csv('normalized_dataset_model.csv')
model
# Out:
#                         learner  train_time  pred_time    f_test   f_train
# 0                 XGBClassifier   31.619051   0.868409  0.786924  0.788579
# 1    GradientBoostingClassifier   36.862017   0.481270  0.782035  0.785070
# 2             BaggingClassifier   22.184455   1.096292  0.758004  0.981055
# 3            AdaBoostClassifier   10.378914   1.019811  0.740820  0.746545
# 4        RandomForestClassifier    4.554178   0.860999  0.738011  0.981394
# 5                 MLPClassifier  485.935418   2.051999  0.736316  0.743308
# 6        DecisionTreeClassifier    3.332131   0.089466  0.731018  0.999037
# 7          ExtraTreesClassifier    4.559558   1.336199  0.691221  0.999037
# 8           ExtraTreeClassifier    0.424107   0.136846  0.660329  0.999037
# 9            LogisticRegression    5.903210   0.013059  0.570117  0.571491
# 10            RidgeClassifierCV    0.550225   0.009949  0.556209  0.558862
# ...

# %%
model = pd.read_csv('targetencoder_dataset_model.csv')
model
# Out:
#                         learner  train_time  pred_time    f_test   f_train
# 0                 MLPClassifier  544.239955   2.433091  0.826153  0.824293
# 1                 XGBClassifier   30.427481   0.793904  0.821093  0.820947
# 2    GradientBoostingClassifier   35.201835   0.459548  0.816577  0.817238
# 3                 SGDClassifier    0.357118   0.010016  0.807736  0.807877
# 4        RandomForestClassifier    3.791564   0.780958  0.796155  0.984663
# 5             BaggingClassifier   21.562073   1.007915  0.794554  0.983260
# 6          ExtraTreesClassifier    4.075972   1.045230  0.787195  0.999030
# 7            LogisticRegression    3.550931   0.009358  0.784447  0.785540
# 8            AdaBoostClassifier   10.589838   0.961912  0.783250  0.785990
# 9             RidgeClassifierCV    0.520056   0.009977  0.775785  0.775445
# 10              RidgeClassifier    0.083332   0.009441  0.775657  0.775421
# ...
