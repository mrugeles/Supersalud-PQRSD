# %%
import pandas as pd

model = pd.read_csv('naive_dataset_model.csv')
model
# Out:
#                         learner   train_time  pred_time    f_test   f_train
# 0             BaggingClassifier   489.156169  10.760848  0.709317  0.967097
# 1        RandomForestClassifier    75.985736   6.863204  0.701293  0.967297
# 2        DecisionTreeClassifier    56.963608   0.856767  0.687723  0.998513
# 3          ExtraTreesClassifier    50.266649   9.118591  0.664780  0.998513
# 4    GradientBoostingClassifier   647.786891   3.901380  0.661018  0.659049
# 5                 XGBClassifier   392.697583   6.970495  0.646411  0.645325
# 6           ExtraTreeClassifier     5.098738   1.034036  0.641540  0.998513
# 7            AdaBoostClassifier   340.749170   8.204528  0.603028  0.603401
# 8   PassiveAggressiveClassifier     3.538327   0.448095  0.502745  0.502957
# 9                 SGDClassifier     3.166825   0.438542  0.371950  0.368267
# 10            RidgeClassifierCV     6.848527   0.413289  0.320337  0.319997
# ...

# %%
model = pd.read_csv('basic_dataset_model.csv')
model
# Out:
#                         learner  train_time  pred_time    f_test   f_train
# 0                 XGBClassifier   28.216854   0.803964  0.789946  0.789971
# 1    GradientBoostingClassifier   31.819922   0.472912  0.787908  0.788513
# 2                 SGDClassifier    0.339456   0.029553  0.781393  0.781719
# 3             BaggingClassifier   19.354779   1.045560  0.761183  0.981434
# 4        RandomForestClassifier    3.632228   0.827152  0.749905  0.981686
# 5            AdaBoostClassifier    8.799966   0.946929  0.742557  0.743541
# 6        DecisionTreeClassifier    2.871899   0.093568  0.733616  0.999208
# 7                 MLPClassifier  296.683279   1.871170  0.726417  0.730958
# 8          ExtraTreesClassifier    3.626182   1.090750  0.703753  0.999208
# 9           ExtraTreeClassifier    0.388423   0.129010  0.662951  0.999208
# 10           LogisticRegression   22.413271   0.028833  0.594884  0.597951
# ...

# %%
model = pd.read_csv('missing_state_dataset_model.csv')
model
# Out:
#                         learner  train_time  pred_time    f_test   f_train
# 0                 XGBClassifier   54.631729   1.032161  0.786597  0.790686
# 1    GradientBoostingClassifier   56.811249   0.705668  0.783447  0.787737
# 2             BaggingClassifier   28.864257   1.339352  0.763491  0.980989
# 3        RandomForestClassifier    4.977574   1.011794  0.744717  0.981549
# 4        DecisionTreeClassifier    3.982649   0.109896  0.733374  0.999089
# 5            AdaBoostClassifier   12.991749   1.108130  0.732205  0.735300
# 6          ExtraTreesClassifier    5.157242   1.306665  0.706307  0.999089
# 7           ExtraTreeClassifier    0.532683   0.160517  0.666214  0.999089
# 8                 MLPClassifier  470.255732   2.228532  0.646924  0.657343
# 9            LogisticRegression   24.863498   0.042238  0.595527  0.600945
# 10              RidgeClassifier    0.188617   0.045933  0.583848  0.589383
# ...

# %%
model = pd.read_csv('missing_state_75_dataset_model.csv')
model
# Out:
#                         learner  train_time  pred_time    f_test   f_train
# 0                 XGBClassifier   42.337720   0.969624  0.786147  0.788380
# 1    GradientBoostingClassifier   43.544953   0.669234  0.783461  0.785799
# 2                 SGDClassifier    0.413409   0.046648  0.783198  0.782897
# 3             BaggingClassifier   22.475800   1.223164  0.761067  0.980898
# 4        RandomForestClassifier    4.116855   0.870188  0.737504  0.981500
# 5                 MLPClassifier  308.205270   2.038620  0.736848  0.738985
# 6            AdaBoostClassifier   10.088655   1.022071  0.734520  0.736755
# 7        DecisionTreeClassifier    3.308703   0.110764  0.732373  0.999192
# 8          ExtraTreesClassifier    4.391915   1.197642  0.687515  0.999192
# 9           ExtraTreeClassifier    0.456883   0.150322  0.659278  0.999192
# 10           LogisticRegression   16.876396   0.043722  0.583172  0.588454
# ...

# %%
model = pd.read_csv('missing_state_impute_dataset_model.csv')
model
# Out:
#                         learner  train_time  pred_time    f_test   f_train
# 0                 XGBClassifier   51.742635   1.085273  0.790200  0.790657
# 1    GradientBoostingClassifier   44.605931   0.766462  0.788649  0.788686
# 2             BaggingClassifier   24.008019   1.387853  0.760775  0.981599
# 3            AdaBoostClassifier   10.543447   1.082919  0.745929  0.746989
# 4                 MLPClassifier  565.404014   4.307006  0.740233  0.743868
# 5        RandomForestClassifier    4.422388   0.938517  0.739446  0.981750
# 6        DecisionTreeClassifier    3.533007   0.117196  0.733246  0.999208
# 7          ExtraTreesClassifier    4.744252   1.263922  0.696919  0.999208
# 8           ExtraTreeClassifier    0.495409   0.160411  0.664638  0.999208
# 9                 SGDClassifier    0.480352   0.057601  0.619459  0.625354
# 10           LogisticRegression   59.063191   0.054096  0.603012  0.604969
# ...

# %%
model = pd.read_csv('impute_dataset_model.csv')
model
# Out:
#                         learner  train_time  pred_time    f_test   f_train
# 0                 XGBClassifier   28.456300   0.838883  0.789946  0.789971
# 1    GradientBoostingClassifier   32.100539   0.482152  0.787908  0.788513
# 2                 SGDClassifier    0.332752   0.031538  0.781393  0.781719
# 3             BaggingClassifier   19.843508   1.046154  0.761183  0.981434
# 4        RandomForestClassifier    3.665893   0.828509  0.749905  0.981686
# 5            AdaBoostClassifier    8.855990   0.935656  0.742557  0.743541
# 6        DecisionTreeClassifier    2.949652   0.096909  0.733616  0.999208
# 7                 MLPClassifier  308.130477   1.948846  0.726417  0.730958
# 8          ExtraTreesClassifier    3.693949   1.128120  0.703753  0.999208
# 9           ExtraTreeClassifier    0.390269   0.138944  0.662951  0.999208
# 10           LogisticRegression   22.372855   0.031149  0.594884  0.597951
# ...

# %%
model = pd.read_csv('normalized_dataset_model.csv')
model
# Out:
#                         learner  train_time  pred_time    f_test   f_train
# 0                 XGBClassifier   29.611142   0.888021  0.789946  0.789971
# 1    GradientBoostingClassifier   32.964547   0.488482  0.787908  0.788513
# 2             BaggingClassifier   20.132923   1.054098  0.761949  0.981531
# 3        RandomForestClassifier    3.791752   0.842165  0.748998  0.981736
# 4            AdaBoostClassifier    8.961204   0.960848  0.742557  0.743541
# 5        DecisionTreeClassifier    2.931714   0.095454  0.733311  0.999208
# 6                 MLPClassifier  364.786459   2.163208  0.730584  0.733608
# 7          ExtraTreesClassifier    3.822370   1.222816  0.703424  0.999208
# 8           ExtraTreeClassifier    0.359565   0.130545  0.680311  0.999208
# 9            LogisticRegression    6.130871   0.011373  0.604777  0.603887
# 10            RidgeClassifierCV    0.508803   0.015285  0.593110  0.591957
# ...

# %%
model = pd.read_csv('targetencoder_dataset_model.csv')
model
# Out:
#                         learner  train_time  pred_time    f_test   f_train
# 0   PassiveAggressiveClassifier    0.353562   0.010700  0.862020  0.859108
# 1                 MLPClassifier  477.627550   2.633684  0.841929  0.841015
# 2                 XGBClassifier   29.379164   0.852773  0.822177  0.820952
# 3    GradientBoostingClassifier   32.310228   0.482649  0.817483  0.816850
# 4        RandomForestClassifier    3.410844   0.783127  0.795874  0.984845
# 5             BaggingClassifier   19.717941   1.023344  0.791644  0.983930
# 6          ExtraTreesClassifier    3.584382   1.027828  0.790059  0.999200
# 7            LogisticRegression    3.841047   0.010912  0.788877  0.786646
# 8            AdaBoostClassifier    8.785661   0.978075  0.786228  0.784215
# 9             RidgeClassifierCV    0.512118   0.016543  0.779168  0.777751
# 10              RidgeClassifier    0.079009   0.009513  0.779102  0.777764
# ...

# %%
model = pd.read_csv('afect_cod_dep_dataset_model.csv')
model
# Out:
#                         learner  train_time  pred_time    f_test   f_train
# 0                 XGBClassifier   34.233629   0.871374  0.822313  0.822226
# 1    GradientBoostingClassifier   44.972782   0.512333  0.815297  0.815246
# 2                 SGDClassifier    0.385749   0.012065  0.814624  0.813031
# 3                 MLPClassifier  435.849844   2.610477  0.806371  0.806536
# 4             BaggingClassifier   24.128136   1.099354  0.795993  0.983411
# 5        RandomForestClassifier    4.309418   0.835138  0.795984  0.984222
# 6          ExtraTreesClassifier    4.394139   1.235053  0.789341  0.999059
# 7            LogisticRegression    4.763793   0.009481  0.786640  0.785920
# 8            AdaBoostClassifier   10.923731   0.989202  0.782663  0.784334
# 9             RidgeClassifierCV    0.609880   0.010939  0.777310  0.776997
# 10              RidgeClassifier    0.093766   0.009775  0.777253  0.776917
# ...

# %%
model = pd.read_csv('cie10_dataset_model.csv')
model
# Out:
#                         learner  train_time  pred_time    f_test   f_train
# 0   PassiveAggressiveClassifier    0.221488   0.007674  0.832904  0.833483
# 1                 SGDClassifier    0.219245   0.007866  0.824634  0.820560
# 2                 MLPClassifier  344.040887   1.972817  0.821850  0.821984
# 3                 XGBClassifier   22.045780   0.604651  0.813392  0.812866
# 4    GradientBoostingClassifier   21.979699   0.345523  0.810926  0.810166
# 5        RandomForestClassifier    2.360004   0.472789  0.788874  0.984086
# 6             BaggingClassifier   13.171087   0.679749  0.788187  0.983617
# 7            AdaBoostClassifier    5.955476   0.646655  0.784517  0.782670
# 8          ExtraTreesClassifier    2.342330   0.586347  0.781356  0.999080
# 9            LogisticRegression    2.196447   0.008196  0.780618  0.778674
# 10              RidgeClassifier    0.059336   0.007077  0.767750  0.766881
# ...

# %%
model = pd.read_csv('cie10_labelencoded_dataset_model.csv')
model
# Out:
#                         learner  train_time  pred_time    f_test   f_train
# 0                 XGBClassifier   23.221571   0.598339  0.792830  0.796119
# 1    GradientBoostingClassifier   24.893782   0.371705  0.790341  0.792001
# 2             BaggingClassifier   15.552687   0.645720  0.758235  0.981419
# 3        RandomForestClassifier    3.177354   0.503717  0.749605  0.983907
# 4            AdaBoostClassifier    6.932963   0.594992  0.746883  0.744414
# 5        DecisionTreeClassifier    2.178391   0.054361  0.727251  0.998980
# 6          ExtraTreesClassifier    2.722065   0.658071  0.700981  0.998980
# 7           ExtraTreeClassifier    0.239022   0.066466  0.675096  0.998980
# 8            LogisticRegression   12.941187   0.022964  0.587219  0.594968
# 9             RidgeClassifierCV    0.513315   0.023653  0.584899  0.590600
# 10              RidgeClassifier    0.103359   0.022930  0.584810  0.590694
# ...
