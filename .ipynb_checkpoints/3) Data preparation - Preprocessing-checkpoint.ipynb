# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json

import data_utils as data_utils

dataset = pd.read_csv("datasets/dataset_clean.csv")

dataset['RIESGO_VIDA'] = dataset['RIESGO_VIDA'].apply(lambda x: 1 if x == 'si' else 0)

labels = dataset[['RIESGO_VIDA']]
features = dataset.drop(['RIESGO_VIDA'], axis = 1)

print(dataset.shape)
dataset.head()
# Out:
# (281311, 29)
#    RIESGO_VIDA                                             CIE_10  \
# 0            0                               otra atención médica
# 1            0                              asma, no especificada
# 2            0  agentes virales como causa de enfermedades cla...
# 3            1  epilepsia y sindromes epilepticos idiopaticos ...
# 4            0                               otra atención médica
#
#   AFEC_TIPOPER           ENT_TIPOVIG     AFEC_MPIO AFEC_PARENTESCO  \
# 0      natural    regimen subsidiado        bogotá            otro
# 1      natural  regimen contributivo          cali      abuelo (a)
# 2      natural  regimen contributivo         neiva           padre
# 3      natural  regimen contributivo  dosquebradas           padre
# 4      natural    regimen subsidiado        bogotá            otro
#
#         AFEC_EDADR                      AFEC_POBESPECIAL  COD_MACROMOT  \
# 0  de 13 a 17 años                             no aplica           1.0
# 1  de 13 a 17 años                             no aplica           1.0
# 2  de 13 a 17 años                             no aplica           1.0
# 3  de 13 a 17 años  persona en condición de discapacidad           1.0
# 4  de 13 a 17 años                             no aplica           1.0
#
#    ENT_COD_MPIO     ...      COD_MOTGEN PET_COD_DEPTO  \
# 0       63130.0     ...           101.0          11.0
# 1       76001.0     ...           103.0          76.0
# 2       41001.0     ...           106.0          41.0
# 3       66001.0     ...           101.0          66.0
# 4       11001.0     ...           106.0          11.0
#
#                   AFEC_EDUC  PQR_TIPOPETICION      PET_MPIO AFEC_GENERO  \
# 0                   ninguno          reclamo         bogotá       mujer
# 1                secundaria          reclamo           cali      hombre
# 2  universitario incompleto          reclamo          neiva      hombre
# 3                   ninguno          reclamo   dosquebradas      hombre
# 4                   ninguno          reclamo         bogotá      hombre
#
#        PQR_CANAL PET_TIPOPER AFEC_REGAFILIACION    AFEC_DPTO
# 0        escrito    juridica         subsidiado  bogota d.c.
# 1     telefonico     natural       contributivo        valle
# 2  personalizado     natural       contributivo        huila
# 3  personalizado     natural       contributivo    risaralda
# 4        escrito    juridica         subsidiado  bogota d.c.
#
# [5 rows x 29 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing

def categorize(df, column, bins):
    data = pd.cut(np.array(df[column]),  bins=bins)
    data = pd.Series(data)
    data = pd.DataFrame(data, columns=[f'{column}_Range'])
    data = data[f'{column}_Range'].apply(lambda value: str(value).replace('(', '').replace(']', '').replace(', ', '_'))

    df = df.join(pd.DataFrame(data, columns=[f'{column}_Range']))
    df = df.join(pd.get_dummies(df[f'{column}_Range']))
    df = df.drop([column], axis = 1)
    return df.drop([f'{column}_Range'], axis = 1)

def one_hot_encode(df, column):
    df = df.join(pd.get_dummies(df[column], prefix = column))
    return df.drop([column], axis = 1)  

def label_encode(df, column):
    le = preprocessing.LabelEncoder()
    values = list(df[column].values)
    le.fit(values)
    df[column] = le.transform(values)
    return df

def scale_normalize(df, columns):
    df[columns] = MinMaxScaler().fit_transform(df[columns])
    for column in columns:
        df[column] = df[column].apply(lambda x: np.log(x + 1))
    return df

def clean_ticket(text):
    text = text.lower()
    return re.sub(r"[^a-zA-Z0-9 ]", "", text)

# %%
columns = [
    'AFEC_EDADR', 
    'AFEC_EDUC', 
    'AFEC_GENERO', 
    'AFEC_GETNICO', 
    'AFEC_PARENTESCO', 
    'AFEC_POBESPECIAL', 
    'AFEC_REGAFILIACION',
    'AFEC_TIPOPER',
    'PET_TIPOPER',
    'PQR_CANAL',
    'RIESGO_VIDA',
    'TRIM'
]
print(f'columns: {dataset.columns}')
for column in columns:
    print(f'{column}: {set(dataset[column].values)}')
# Out:
# columns: Index(['RIESGO_VIDA', 'CIE_10', 'AFEC_TIPOPER', 'ENT_TIPOVIG', 'AFEC_MPIO',
#        'AFEC_PARENTESCO', 'AFEC_EDADR', 'AFEC_POBESPECIAL', 'COD_MACROMOT',
#        'ENT_COD_MPIO', 'ENT_COD_SNS', 'ENT_TIPOVIG_SNS', 'TRIM', 'MES',
#        'COD_MOTESP', 'AFEC_GETNICO', 'ENT_COD_DEPTO', 'PQR_CLASE_SNS',
#        'PATOLOGIA_TIPO', 'COD_MOTGEN', 'PET_COD_DEPTO', 'AFEC_EDUC',
#        'PQR_TIPOPETICION', 'PET_MPIO', 'AFEC_GENERO', 'PQR_CANAL',
#        'PET_TIPOPER', 'AFEC_REGAFILIACION', 'AFEC_DPTO'],
#       dtype='object')
# AFEC_EDADR: {'de 0 a 5 años', 'de 18 a 24 años', 'de 38 a 49 años', 'de 25 a 29 años', 'de 13 a 17 años', 'de 6 a 12 años', 'de 50 a 62 años', 'mayor de 63 años', 'de 30 a 37 años'}
# AFEC_EDUC: {'primaria incompleta', 'universitario', 'universitario incompleto', 'secundaria', 'posgrado', 'primaria', 'ninguno', 'secundaria incompleta'}
# AFEC_GENERO: {'hombre', 'mujer'}
# AFEC_GETNICO: {'palanquero (de san basilio)', 'negro', 'raizal (del archipiélago de san andrés y providencia)', 'rom- gitano', 'afrocolombiano o afrodescendiente', 'mulato', 'no aplica', 'indígena'}
# AFEC_PARENTESCO: {'ciudador (a)', 'empleador', 'nombre propio', 'padre', 'hijo (a)', 'hermano (a)', 'ips', 'abuelo (a)', 'veedor', 'otro', 'amigo (a)', 'madre', 'tio (a)', 'nieto (a)', 'conyugue', 'representante legal'}
# AFEC_POBESPECIAL: {'desplazado', 'mujer en estado de gestación', 'población carcelaria (presos)', 'violencia de genero', 'persona en condición de discapacidad', 'habitante de la calle', 'no aplica', 'trabajador sexual'}
# AFEC_REGAFILIACION: {'régimen especial', 'ppna', 'particular', 'contributivo', 'subsidiado'}
# AFEC_TIPOPER: {'juridica', 'natural'}
# PET_TIPOPER: {'juridica', 'natural'}
# PQR_CANAL: {'escrito', 'correo', 'web', 'chat', 'personalizado', 'telefonico'}
# RIESGO_VIDA: {0, 1}
# TRIM: {'trim iii', 'trim i', 'trim ii', 'trim iv'}

# %%
list(set(dataset.columns) - set(columns))
# Out:
# ['AFEC_DPTO',
#  'COD_MOTGEN',
#  'COD_MACROMOT',
#  'ENT_COD_SNS',
#  'AFEC_MPIO',
#  'ENT_COD_DEPTO',
#  'ENT_TIPOVIG',
#  'PQR_CLASE_SNS',
#  'CIE_10',
#  'PET_COD_DEPTO',
#  'PET_MPIO',
#  'COD_MOTESP',
#  'ENT_COD_MPIO',
#  'ENT_TIPOVIG_SNS',
#  'PQR_TIPOPETICION',
#  'PATOLOGIA_TIPO',
#  'MES']

# %%
def pre_process(df, train = True):
    
        df = label_encode(df, 'AFEC_EDADR')
        df = one_hot_encode(df, 'AFEC_EDADR')
        df = label_encode(df, 'AFEC_EDUC')
        df = one_hot_encode(df, 'AFEC_EDUC')
        
        df = one_hot_encode(df, 'AFEC_GENERO')
        
        df = label_encode(df, 'AFEC_GETNICO')
        df = one_hot_encode(df, 'AFEC_GETNICO')
        
        df = label_encode(df, 'AFEC_PARENTESCO')
        df = one_hot_encode(df, 'AFEC_PARENTESCO')

        df = label_encode(df, 'AFEC_POBESPECIAL')
        df = one_hot_encode(df, 'AFEC_POBESPECIAL')
 
        df = one_hot_encode(df, 'AFEC_REGAFILIACION')
        df = one_hot_encode(df, 'AFEC_TIPOPER')
        df = one_hot_encode(df, 'PET_TIPOPER')
        df = one_hot_encode(df, 'PQR_CANAL')
        df = one_hot_encode(df, 'RIESGO_VIDA')
        df = one_hot_encode(df, 'TRIM')
    
        
        #df = one_hot_encode(df, 'PQR_TIPOATENCION')

        if(train == True):
            df = df.drop_duplicates()

        encoded_columns = ['AFEC_DPTO',
             'COD_MOTGEN',
             'COD_MACROMOT',
             'ENT_COD_SNS',
             'AFEC_MPIO',
             'ENT_COD_DEPTO',
             'ENT_TIPOVIG',
             'PQR_CLASE_SNS',
             'CIE_10',
             'PET_COD_DEPTO',
             'PET_MPIO',
             'COD_MOTESP',
             'ENT_COD_MPIO',
             'ENT_TIPOVIG_SNS',
             'PQR_TIPOPETICION',
             'PATOLOGIA_TIPO',
             'MES']
        for column in encoded_columns:
            df = label_encode(df, column)
            
        df = scale_normalize(df, encoded_columns)
        return df

# %%
nulls = set(dataset.columns[dataset.isnull().mean() > 0])
print(len(nulls))
print(nulls)
# Out:
# 0
# set()

# %% [markdown]
# ## Encoding dataset
# All features in the dataset are categorical. Some of them have too many classes to be one hot encoded. Mean encoding transformation will be perform on the dataset to encode features.

# %%
encoded_features = pre_process(dataset)
display(encoded_features.head())

# %% [markdown]
# ## Store processed dataset

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

encoded_features['RIESGO_VIDA'] = labels

encoded_features.to_csv("datasets/encoded_dataset.csv", index = False)

# %% [markdown]
# ## Post Processing Exploration

# %%
import seaborn as sns
plt.figure(figsize=(16, 16))

ax = sns.heatmap(encoded_features.corr(), cmap = "RdBu_r", annot=True, fmt='.1f')
