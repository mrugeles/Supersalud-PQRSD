# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json

import data_utils as data_utils

dataset = pd.read_csv("datasets/dataset_clean.csv")

labels = dataset[['RIESGO_VIDA']]
features = dataset.drop(['RIESGO_VIDA'], axis = 1)

dataset.head()
# Out:
#      AFEC_DPTO       AFEC_EDADR                 AFEC_EDUC AFEC_GENERO  \
# 0  bogota d.c.  de 13 a 17 aÑos                   ninguno       mujer
# 1        valle  de 13 a 17 aÑos                secundaria      hombre
# 2        huila  de 13 a 17 aÑos  universitario incompleto      hombre
# 3    risaralda  de 13 a 17 aÑos                   ninguno      hombre
# 4  bogota d.c.  de 13 a 17 aÑos                   ninguno      hombre
#
#   AFEC_GETNICO     AFEC_MPIO AFEC_PARENTESCO  \
# 0    no aplica        bogotÁ            otro
# 1    no aplica          cali      abuelo (a)
# 2    no aplica         neiva           padre
# 3    no aplica  dosquebradas           padre
# 4    no aplica        bogotÁ            otro
#
#                        AFEC_POBESPECIAL AFEC_REGAFILIACION AFEC_TIPOPER  \
# 0                             no aplica         subsidiado      natural
# 1                             no aplica       contributivo      natural
# 2                             no aplica       contributivo      natural
# 3  persona en condición de discapacidad       contributivo      natural
# 4                             no aplica         subsidiado      natural
#
#     ...                                       PATOLOGIA_TIPO PET_COD_DEPTO  \
# 0   ...    problemas relacionados con facilidades de aten...            11
# 1   ...    problemas relacionados con facilidades de aten...            76
# 2   ...    problemas relacionados con facilidades de aten...            41
# 3   ...                                            epilepsia            66
# 4   ...    problemas relacionados con facilidades de aten...            11
#
#        PET_MPIO  PET_TIPOPER      PQR_CANAL PQR_CLASE_SNS  PQR_TIPOATENCION  \
# 0        bogotÁ     juridica        escrito           pqr  peticion directa
# 1          cali      natural     telefonico           pqr                 0
# 2         neiva      natural  personalizado           pqr                 0
# 3  dosquebradas      natural  personalizado           pqr                 0
# 4        bogotÁ     juridica        escrito           pqr  peticion directa
#
#    PQR_TIPOPETICION RIESGO_VIDA    TRIM
# 0          reclamo            0  trim i
# 1          reclamo            0  trim i
# 2          reclamo            0  trim i
# 3          reclamo            1  trim i
# 4          reclamo            0  trim i
#
# [5 rows x 36 columns]

# %% [markdown]
# ## Encoding dataset
# All features in the dataset are categorical. Some of them have too many classes to be one hot encoded. Mean encoding transformation will be perform on the dataset to encode features.

# %%
encoded_features = data_utils.encode_features(features, labels)
display(encoded_features.head(n = 5))
# Out:
# --- 278.588389158 seconds ---
#    AFEC_DPTO  AFEC_EDADR  AFEC_EDUC  AFEC_GENERO  AFEC_GETNICO  AFEC_MPIO  \
# 0   0.413632    0.457947   0.404291     0.422006       0.43569   0.411426
# 1   0.367341    0.457947   0.447575     0.455866       0.43569   0.371084
# 2   0.557791    0.457947   0.488072     0.455866       0.43569   0.564257
# 3   0.409106    0.457947   0.404291     0.455866       0.43569   0.445723
# 4   0.413632    0.457947   0.404291     0.455866       0.43569   0.411426
#
#    AFEC_PARENTESCO  AFEC_POBESPECIAL  AFEC_REGAFILIACION  AFEC_TIPOPER  \
# 0         0.498799          0.425020            0.488333      0.436371
# 1         0.459542          0.425020            0.420733      0.436371
# 2         0.532725          0.425020            0.420733      0.436371
# 3         0.532725          0.526102            0.420733      0.436371
# 4         0.498799          0.425020            0.488333      0.436371
#
#     ...    PATOLOGIA_1  PATOLOGIA_TIPO  PET_COD_DEPTO  PET_MPIO  PET_TIPOPER  \
# 0   ...       0.388499        0.388499       0.416195  0.420014     0.271184
# 1   ...       0.388499        0.388499       0.375220  0.366720     0.433927
# 2   ...       0.388499        0.388499       0.549517  0.558897     0.433927
# 3   ...       0.450952        0.450952       0.407647  0.447220     0.433927
# 4   ...       0.388499        0.388499       0.416195  0.420014     0.271184
#
#    PQR_CANAL  PQR_CLASE_SNS  PQR_TIPOATENCION  PQR_TIPOPETICION    TRIM
# 0   0.168226       0.457652          0.266635          0.456139  0.4024
# 1   0.281359       0.457652          0.459141          0.456139  0.4024
# 2   0.616036       0.457652          0.459141          0.456139  0.4024
# 3   0.616036       0.457652          0.459141          0.456139  0.4024
# 4   0.168226       0.457652          0.266635          0.456139  0.4024
#
# [5 rows x 35 columns]

# %%
# Normalization with QuantileTransformer
from sklearn.preprocessing import QuantileTransformer
features_columns = features_raw.columns.values.tolist()

scaler = QuantileTransformer()

features_log_minmax_transform = pd.DataFrame(data = encoded_features)
features_log_minmax_transform[features_columns] = scaler.fit_transform(encoded_features[features_columns])


encoded_features = features_log_minmax_transform
# Out:
# array([[4.60460460e-01, 6.57157157e-01, 2.55255255e-01, ...,
#         7.75775776e-02, 2.85285285e-01, 3.84384384e-01],
#        [2.70770771e-01, 6.57157157e-01, 5.36536537e-01, ...,
#         9.99999900e-01, 2.85285285e-01, 3.84384384e-01],
#        [9.57457457e-01, 6.57157157e-01, 9.31931932e-01, ...,
#         9.99999900e-01, 2.85285285e-01, 3.84384384e-01],
#        ...,
#        [6.97697698e-01, 4.26426426e-01, 2.55255255e-01, ...,
#         7.75775776e-02, 2.79779780e-01, 9.99999998e-08],
#        [4.60460460e-01, 1.87687688e-01, 2.55255255e-01, ...,
#         7.75775776e-02, 2.79779780e-01, 9.99999998e-08],
#        [4.60460460e-01, 8.03553554e-01, 2.55255255e-01, ...,
#         7.75775776e-02, 2.79779780e-01, 9.99999998e-08]])

# %% [markdown]
# ## Store processed dataset

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

encoded_features['RIESGO_VIDA'] = labels

encoded_features.to_csv("datasets/encoded_dataset.csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-11da65e1d971> in <module>()
#       2 from sklearn.model_selection import train_test_split
#       3
# ----> 4 encoded_features['RIESGO_VIDA'] = labels
#       5
#       6 encoded_features.to_csv("datasets/encoded_dataset.csv", index = False)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %% [markdown]
# ## Post Processing Exploration

# %%
import seaborn as sns
plt.figure(figsize=(16, 16))

ax = sns.heatmap(encoded_features.corr(), cmap = "RdBu_r", annot=True, fmt='.1f')
