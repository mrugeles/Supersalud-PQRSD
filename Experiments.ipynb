# %%
import pandas as pd
import experiment_datasets as datax
from IPython.display import display, Markdown, Latex

for dataset_name in datax.experiment:
    display(Markdown(f'# Results {dataset_name}'))
    print(f'datasets/experiments/{dataset_name}_results.csv')
    dataset = pd.read_csv(f'datasets/experiments/{dataset_name}_results.csv')
    display(dataset)
# Out:
# # Results naive
# datasets/experiments/naive_results.csv
#                         learner  train_time  pred_time    f_test   f_train
# 0             BaggingClassifier   15.634590   0.694055  0.689829  0.964219
# 1        RandomForestClassifier    2.464556   0.412965  0.669890  0.966547
# 2    GradientBoostingClassifier   30.108169   0.361017  0.667844  0.654534
# 3                 XGBClassifier   30.373479   0.595449  0.665826  0.645753
# 4        DecisionTreeClassifier    2.413878   0.056044  0.665090  0.999715
# 5                 MLPClassifier  292.502081   1.715149  0.651265  0.650460
# 6            AdaBoostClassifier    8.856148   0.761244  0.628592  0.608480
# 7          ExtraTreesClassifier    2.395977   0.513708  0.612035  0.999715
# 8           ExtraTreeClassifier    0.215462   0.064659  0.603311  0.999715
# 9            LogisticRegression    8.387624   0.025310  0.312134  0.307870
# 10            RidgeClassifierCV    0.596863   0.023335  0.199213  0.199196
# 11              RidgeClassifier    0.116571   0.024602  0.195556  0.198920
# 12                SGDClassifier    0.256840   0.027639  0.086005  0.080773
# 13  PassiveAggressiveClassifier    0.316796   0.024007  0.002599  0.001059
# # Results basic
# datasets/experiments/basic_results.csv
#                         learner   train_time  pred_time    f_test   f_train
# 0        RandomForestClassifier    93.281924  13.704001  0.796416  0.999971
# 1                 XGBClassifier    53.674536   1.387997  0.785069  0.790796
# 2    GradientBoostingClassifier   124.682008   0.859995  0.783435  0.787806
# 3          ExtraTreesClassifier   101.750484  21.024755  0.766110  1.000000
# 4             BaggingClassifier    48.166996   2.643000  0.762382  0.981539
# 5            AdaBoostClassifier    27.099986   5.046999  0.736154  0.742058
# 6        DecisionTreeClassifier     6.284004   0.171996  0.732814  1.000000
# 7           ExtraTreeClassifier     0.806995   0.200002  0.657251  1.000000
# 8               RidgeClassifier     0.487995   0.089000  0.578302  0.584649
# 9             RidgeClassifierCV     1.353993   0.086998  0.573049  0.575900
# 10                MLPClassifier  1086.152337   5.307997  0.471215  0.473266
# 11           LogisticRegression     4.772002   0.084992  0.278777  0.286192
# 12                SGDClassifier    47.882058   0.100000  0.103936  0.110901
# 13  PassiveAggressiveClassifier     1.080999   0.082016  0.000000  0.000161
# # Results missing_state
# datasets/experiments/missing_state_results.csv
#                         learner  train_time  pred_time    f_test   f_train
# 0                 SGDClassifier   69.294991   0.144000  0.797923  0.798493
# 1        RandomForestClassifier   74.857006  15.679991  0.789316  0.999392
# 2                 XGBClassifier   72.575167   1.592960  0.787046  0.791222
# 3    GradientBoostingClassifier  109.344532   1.057997  0.783635  0.787847
# 4             BaggingClassifier   51.019991   2.906003  0.766218  0.981116
# 5                 MLPClassifier  762.782024   4.733003  0.761237  0.767127
# 6          ExtraTreesClassifier   86.020380  21.211329  0.758734  0.999089
# 7   PassiveAggressiveClassifier    4.575919   0.147998  0.753694  0.754316
# 8        DecisionTreeClassifier    6.277004   0.206995  0.739217  0.999089
# 9            AdaBoostClassifier   35.667170   9.908901  0.736154  0.742058
# 10          ExtraTreeClassifier    0.834998   0.232996  0.667374  0.999089
# 11              RidgeClassifier    0.720124   0.153001  0.582730  0.588282
# 12            RidgeClassifierCV    2.637982   0.179001  0.582730  0.588307
# 13           LogisticRegression    5.103083   0.148001  0.385877  0.387814
# # Results missing_state_remove_75_percent
# datasets/experiments/missing_state_remove_75_percent_results.csv
#                         learner   train_time  pred_time    f_test   f_train
# 0        RandomForestClassifier    84.690289  16.321223  0.787689  0.999394
# 1                 XGBClassifier    76.878721   1.678885  0.780987  0.786634
# 2    GradientBoostingClassifier   110.739045   1.037003  0.780616  0.785137
# 3             BaggingClassifier    47.515053   2.843016  0.762140  0.980953
# 4          ExtraTreesClassifier    90.878527  18.947071  0.753166  0.999059
# 5            AdaBoostClassifier    35.054149   7.406999  0.738884  0.744214
# 6        DecisionTreeClassifier     7.497997   0.219001  0.736999  0.999059
# 7                 MLPClassifier  1018.979984   5.488002  0.736126  0.743286
# 8           ExtraTreeClassifier     1.114002   0.321998  0.663349  0.999059
# 9             RidgeClassifierCV     2.534001   0.154999  0.565832  0.574859
# 10              RidgeClassifier     0.729998   0.141003  0.565812  0.574864
# 11                SGDClassifier    69.634834   0.161996  0.509740  0.514567
# 12           LogisticRegression     7.500755   0.161000  0.448759  0.447143
# 13  PassiveAggressiveClassifier     4.062665   0.137958  0.252064  0.252584
# # Results missing_state_and_imputing
# datasets/experiments/missing_state_and_imputing_results.csv
#                         learner   train_time  pred_time    f_test   f_train
# 0        RandomForestClassifier    69.542995  12.938000  0.791782  0.999416
# 1                 XGBClassifier    74.214062   1.722172  0.787601  0.791125
# 2    GradientBoostingClassifier    94.247572   0.994995  0.786213  0.789596
# 3             BaggingClassifier    42.292000   3.447999  0.765896  0.980886
# 4          ExtraTreesClassifier    81.248001  17.850999  0.756937  0.999089
# 5   PassiveAggressiveClassifier     4.676002   0.167997  0.747083  0.748839
# 6            AdaBoostClassifier    30.953000   6.292051  0.745754  0.751850
# 7        DecisionTreeClassifier     5.911993   0.202038  0.734864  0.999089
# 8                 MLPClassifier  1622.641294  10.265999  0.670806  0.676945
# 9           ExtraTreeClassifier     0.832988   0.257962  0.664559  0.999089
# 10              RidgeClassifier     0.826000   0.200999  0.582881  0.588344
# 11            RidgeClassifierCV     2.784991   0.172003  0.582796  0.588360
# 12           LogisticRegression     5.102698   0.173003  0.423799  0.434845
# 13                SGDClassifier    72.535262   0.165962  0.123071  0.124968
# # Results imputing
# datasets/experiments/imputing_results.csv
#                         learner  train_time  pred_time    f_test   f_train
# 0                 SGDClassifier   35.159998   0.086001  0.798897  0.799391
# 1        RandomForestClassifier   71.657992  13.838003  0.793977  0.999445
# 2                 XGBClassifier   49.076302   1.147788  0.787046  0.791222
# 3    GradientBoostingClassifier   98.615466   0.807003  0.783635  0.787847
# 4             BaggingClassifier   36.790000   2.052000  0.766918  0.981066
# 5          ExtraTreesClassifier   75.925073  19.200997  0.761761  0.999089
# 6                 MLPClassifier  864.242133   4.334000  0.755440  0.765258
# 7   PassiveAggressiveClassifier    3.079996   0.069000  0.753339  0.753881
# 8        DecisionTreeClassifier    5.029999   0.145999  0.738650  0.999089
# 9            AdaBoostClassifier   25.496999   4.542000  0.736154  0.742058
# 10          ExtraTreeClassifier    0.647007   0.186030  0.661465  0.999089
# 11            RidgeClassifierCV    1.321993   0.072000  0.577094  0.581204
# 12              RidgeClassifier    0.438997   0.093002  0.576867  0.581230
# 13           LogisticRegression    4.149997   0.077998  0.279144  0.281078
# # Results normalizing
# datasets/experiments/normalizing_results.csv
#                         learner  train_time  pred_time    f_test   f_train
# 0        RandomForestClassifier   60.892998  11.706002  0.794936  0.999445
# 1                 XGBClassifier   39.514001   1.657997  0.787046  0.791222
# 2    GradientBoostingClassifier   76.385996   0.631999  0.783635  0.787847
# 3                 SGDClassifier    1.453000   0.023006  0.781424  0.779176
# 4   PassiveAggressiveClassifier    0.605109   0.022002  0.772973  0.775442
# 5             BaggingClassifier   32.270998   1.856003  0.767429  0.980926
# 6          ExtraTreesClassifier   61.342001  16.067996  0.755764  0.999089
# 7                 MLPClassifier  876.566999   4.263999  0.740808  0.746345
# 8        DecisionTreeClassifier    5.270006   0.148996  0.737927  0.999089
# 9            AdaBoostClassifier   19.516997   3.732002  0.736154  0.742058
# 10          ExtraTreeClassifier    0.687999   0.235004  0.679324  0.999089
# 11           LogisticRegression    3.785361   0.025004  0.602954  0.599259
# 12            RidgeClassifierCV    1.232985   0.026000  0.595343  0.591634
# 13              RidgeClassifier    0.395959   0.024004  0.594772  0.591185
# # Results target_encoder
# datasets/experiments/target_encoder_results.csv
#                         learner   train_time  pred_time    f_test   f_train
# 0        RandomForestClassifier    96.298996  13.438002  0.832878  0.999429
# 1          ExtraTreesClassifier    67.828997  14.265997  0.828204  0.999081
# 2                 XGBClassifier    51.162057   1.257009  0.820126  0.819328
# 3    GradientBoostingClassifier    76.713767   0.717002  0.817586  0.816751
# 4             BaggingClassifier    32.745080   1.888003  0.798155  0.983259
# 5                 SGDClassifier     1.182008   0.066994  0.795965  0.795000
# 6                 MLPClassifier  1315.047925   6.112005  0.788707  0.787475
# 7            LogisticRegression     5.204987   0.027000  0.787735  0.787088
# 8            AdaBoostClassifier    20.566995   3.899041  0.786204  0.787834
# 9               RidgeClassifier     0.412998   0.026001  0.777467  0.777845
# 10            RidgeClassifierCV     1.367993   0.029003  0.777441  0.777834
# 11       DecisionTreeClassifier     5.268998   0.158999  0.763063  0.999081
# 12          ExtraTreeClassifier     0.829006   0.179992  0.752404  0.999081
# 13  PassiveAggressiveClassifier     0.879587   0.026001  0.456173  0.457924
# # Results cie10
# datasets/experiments/cie10_results.csv
#                         learner  train_time  pred_time    f_test   f_train
# 0        RandomForestClassifier   42.350523   6.105999  0.822048  0.999399
# 1          ExtraTreesClassifier   38.697485   8.660040  0.817468  0.998991
# 2                 XGBClassifier   26.297998   0.751005  0.809924  0.810384
# 3    GradientBoostingClassifier   55.393593   0.468003  0.808337  0.809469
# 4                 SGDClassifier    0.604998   0.017005  0.796612  0.800901
# 5            AdaBoostClassifier   14.171999   3.507003  0.782416  0.781874
# 6             BaggingClassifier   26.310999   1.195001  0.780927  0.983099
# 7            LogisticRegression    2.333998   0.017000  0.780033  0.780824
# 8               RidgeClassifier    0.257999   0.018000  0.772901  0.774639
# 9             RidgeClassifierCV    0.901003   0.018999  0.772901  0.774639
# 10                MLPClassifier  687.984476   3.798001  0.763710  0.767475
# 11       DecisionTreeClassifier    2.939998   0.081006  0.757758  0.998991
# 12          ExtraTreeClassifier    0.393998   0.100000  0.737316  0.998991
# 13  PassiveAggressiveClassifier    0.374005   0.016002  0.704691  0.709437
# # Results target_encoder_only_complains
# datasets/experiments/target_encoder_only_complains_results.csv
#                         learner  train_time  pred_time    f_test   f_train
# 0        RandomForestClassifier   65.472996  11.937006  0.823179  0.999452
# 1          ExtraTreesClassifier   67.763593  15.931611  0.817316  0.999046
# 2                 XGBClassifier   43.609324   1.117001  0.808692  0.818577
# 3                 MLPClassifier  986.593685   5.440002  0.806452  0.817162
# 4    GradientBoostingClassifier   79.864995   0.697043  0.804979  0.815883
# 5                 SGDClassifier    0.871001   0.026000  0.791603  0.803115
# 6             BaggingClassifier   36.622707   1.929004  0.786115  0.983249
# 7            LogisticRegression    4.054993   0.031001  0.778169  0.788435
# 8            AdaBoostClassifier   22.304058   4.601573  0.777399  0.789126
# 9               RidgeClassifier    0.391999   0.028999  0.771250  0.782954
# 10            RidgeClassifierCV    1.229803   0.026002  0.771109  0.782978
# 11       DecisionTreeClassifier    5.437999   0.158003  0.755846  0.999046
# 12          ExtraTreeClassifier    0.686998   0.181007  0.737685  0.999046
# 13  PassiveAggressiveClassifier    0.833998   0.026003  0.166007  0.174142
# # Results cie10_only_complains
# datasets/experiments/cie10_only_complains_results.csv
#                         learner  train_time  pred_time    f_test   f_train
# 0        RandomForestClassifier   37.500051   5.663012  0.831573  0.999307
# 1          ExtraTreesClassifier   40.719999   7.986037  0.831081  0.998895
# 2                 MLPClassifier  670.439578   3.629001  0.825419  0.819347
# 3                 XGBClassifier   25.911996   0.770993  0.816180  0.810819
# 4    GradientBoostingClassifier   50.574001   0.432999  0.815657  0.809403
# 5                 SGDClassifier    0.586998   0.017004  0.805060  0.798088
# 6             BaggingClassifier   22.212997   1.251996  0.792528  0.983334
# 7            LogisticRegression    2.301999   0.019035  0.791494  0.782078
# 8            AdaBoostClassifier   13.498003   2.735995  0.788440  0.782040
# 9               RidgeClassifier    0.267000   0.018998  0.782852  0.774482
# 10            RidgeClassifierCV    0.870995   0.015009  0.782852  0.774482
# 11       DecisionTreeClassifier    3.013967   0.085000  0.765701  0.998895
# 12          ExtraTreeClassifier    0.395993   0.096001  0.744502  0.998895
# 13  PassiveAggressiveClassifier    0.522000   0.017002  0.741995  0.737148
