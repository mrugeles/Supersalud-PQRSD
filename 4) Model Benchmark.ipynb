# %%
import numpy as np
import pandas as pd
from time import time
import matplotlib.pyplot as plt
from IPython.display import display 


# Pretty display for notebooks
# %matplotlib inline
pd.set_option('display.max_colwidth', -1)

dataset = pd.read_csv("datasets/encoded_dataset.csv")
display(dataset.head(n = 5))

labels = dataset[['RIESGO_VIDA']]
features = dataset.drop(['RIESGO_VIDA'], axis = 1)
# Out:
#    AFEC_DPTO  AFEC_EDADR  AFEC_EDUC  AFEC_GENERO  AFEC_GETNICO  AFEC_MPIO  \
# 0  0.137201   0.200671    0.117783   0.693147     0.485508      0.094359
# 1  0.648027   0.200671    0.485508   0.405465     0.485508      0.121797
# 2  0.424883   0.200671    0.693147   0.405465     0.485508      0.434276
# 3  0.567984   0.200671    0.117783   0.405465     0.485508      0.230358
# 4  0.137201   0.200671    0.117783   0.405465     0.485508      0.094359
#
#    AFEC_PARENTESCO  AFEC_POBESPECIAL  AFEC_REGAFILIACION  AFEC_TIPOPER  ...  \
# 0  0.559616         0.405465          0.693147            0.693147      ...
# 1  0.060625         0.405465          0.182322            0.693147      ...
# 2  0.594707         0.405465          0.182322            0.693147      ...
# 3  0.594707         0.485508          0.182322            0.693147      ...
# 4  0.559616         0.405465          0.693147            0.693147      ...
#
# ...

# %%
#set(dataset['ENT_COD_DEPTO'].values)
#set(dataset['ENT_COD_MPIO'].values)
#set(dataset['IDPATOLOGIA_2'].values)
#set(dataset['PET_COD_DEPTO'].values)

# %%
for column in dataset.columns:
    print(f"{column}: isinf: {set(np.isinf(dataset[column]).values)}")
# Out:
# AFEC_DPTO: isinf: {False}
# AFEC_EDADR: isinf: {False}
# AFEC_EDUC: isinf: {False}
# AFEC_GENERO: isinf: {False}
# AFEC_GETNICO: isinf: {False}
# AFEC_MPIO: isinf: {False}
# AFEC_PARENTESCO: isinf: {False}
# AFEC_POBESPECIAL: isinf: {False}
# AFEC_REGAFILIACION: isinf: {False}
# AFEC_TIPOPER: isinf: {False}
# CIE_10: isinf: {False}
# COD_MACROMOT: isinf: {False}
# COD_MOTESP: isinf: {False}
# COD_MOTGEN: isinf: {False}
# ENT_AMBITOIVC: isinf: {False}
# ENT_COD_DEPTO: isinf: {False}
# ENT_COD_MPIO: isinf: {False}
# ENT_COD_SNS: isinf: {False}
# ENT_MPIO_DANE: isinf: {False}
# ENT_NOMBRE: isinf: {False}
# ENT_TIPOVIG: isinf: {False}
# ENT_TIPOVIG_SNS: isinf: {False}
# IDPATOLOGIA_2: isinf: {False}
# MES: isinf: {False}
# PATOLOGIA_1: isinf: {False}
# PATOLOGIA_TIPO: isinf: {False}
# PET_COD_DEPTO: isinf: {False}
# PET_MPIO: isinf: {False}
# PET_TIPOPER: isinf: {False}
# PQR_CANAL: isinf: {False}
# PQR_CLASE_SNS: isinf: {False}
# PQR_TIPOPETICION: isinf: {False}
# TRIM: isinf: {False}
# ...

# %% [markdown]
# ## Shuffle and Split Data

# %%
# Import train_test_split
from sklearn.model_selection import train_test_split

# Split the 'features' and 'labels' data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, 
                                                    labels, 
                                                    test_size = 0.20, 
                                                    random_state = 10)

# Show the results of the split
print("features_final set has {} samples.".format(features.shape[0]))
print("Training set has {} samples.".format(X_train.shape[0]))
print("Testing set has {} samples.".format(X_test.shape[0]))
# Out:
# features_final set has 281311 samples.
# Training set has 225048 samples.
# Testing set has 56263 samples.

# %% [markdown]
# ### Benchmark model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import fbeta_score

clf = LogisticRegression(random_state = 300)
clf = clf.fit(X_train, y_train)
predictions_test = clf.predict(X_test)

f_test =  fbeta_score(y_test, predictions_test, 2)
print(f_test)
# Out:
# C:\Users\mrugeles\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mrugeles\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.5860867800737258
